# %%
import cv2
import matplotlib.pyplot as plt

# %%
video = cv2.VideoCapture("/home/yami/2024_image2/video1/1.mp4")

ret, frame = video.read()

# %%
plt.imshow(frame)

# %%
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
video = cv2.VideoCapture("/home/yami/2024_image2/video1/4.mp4")
num = 0         #计数帧
num1 = 1519
save_step = 10   #间隔帧
while True:
      ret, frame = video.read()
      if not ret:
        break
      num += 1
      if num % save_step == 0:
        cv2.imwrite("/home/yami/2024_image2/5.24/images/" + str(num1) + ".jpg", frame)
        num1 += 1
